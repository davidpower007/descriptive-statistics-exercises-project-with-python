# %% [markdown]
# <a href="https://colab.research.google.com/github/davidpower007/descriptive-statistics-exercises-project-with-python/blob/main/descriptive_statistics_proyecto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import skew, kurtosis, mode

# %%
url = "https://raw.githubusercontent.com/4GeeksAcademy/descriptive-statistics-exercises-project-with-python/refs/heads/main/assets/imdb_1000.csv"
df = pd.read_csv(url)
df.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
#Calcular la longitud del título (en caracteres).

df["title_length"] = df["title"].apply(len)

# %%
#Obtener métricas estadísticas clave: media, mediana, moda, rango, varianza, desviación estándar, asimetría y curtosis.
df["title_length"].describe()
# Out:
# count    979.000000
# mean      15.481103
# std        8.491569
# min        1.000000
# 25%       10.000000
# 50%       14.000000
# 75%       19.000000
# max       68.000000
# Name: title_length, dtype: float64

# %%
df["title_length"].mode()
# Out:
# 0    12
# Name: title_length, dtype: int64

# %%
df["title_length"].var()
# Out:
# 72.10674888402845

# %%
df["title_length"].kurt()
# Out:
# np.float64(3.8122887061291544)

# %%
df["title_length"].skew()
# Out:
# np.float64(1.5252523464631278)

# %%
df["title_length"].describe()["max"] - df["title_length"].describe()["min"]
# Out:
# np.float64(67.0)

# %%
#Identificar los títulos más largos y más cortos
titulo_mas_corto = df.loc[df["title_length"].idxmin(), "title"]
titulo_mas_largo = df.loc[df["title_length"].idxmax(), "title"]
print(titulo_mas_corto)
print(titulo_mas_largo)
# Out:
# M
# Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb

# %%
#Visualizar la distribución de estas longitudes con un histograma y una curva de densidad.
# grafica tus resultados
plt.figure(figsize=(10, 6))
plt.hist(df["title_length"], bins=20, edgecolor="red", alpha=0.7)
plt.title("Distribución de la longitud de los títulos")
plt.xlabel("Cantidad de caracteres")
plt.ylabel("Frecuencia")
plt.grid(True)
plt.show()

# %%
#Ejercicio 2
df["title_length"].head()
# Out:
# 0    24
# 1    13
# 2    22
# 3    15
# 4    12
# Name: title_length, dtype: int64

# %%
#Crea una lista con 5 valores reales de df
data = [24, 13, 22, 15, 12]

# %%
# Calcula la media de los 5 valores
media_data = sum(data) / len(data)
media_data
# Out:
# 17.2

# %%
# Calcula las diferencias al cuadrado con respecto a la media
suma_diferencias = sum((x - media_data)**2 for x in data)
print(suma_diferencias)
# Out:
# 118.8

# %%
# Calcula la varianza (promedio de las diferencias al cuadrado) y su raíz cuadrada para obtener la desviación
varianza_promedio = suma_diferencias/len(data)
varianza_promedio
# Out:
# 23.759999999999998

# %%
desviacion = varianza_promedio ** 0.5
desviacion
# Out:
# 4.874423042781576
